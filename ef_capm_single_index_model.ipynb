# %%
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import yfinance as yf
from pypfopt import risk_models,EfficientFrontier,expected_returns
from pypfopt.discrete_allocation import DiscreteAllocation,get_latest_prices
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")

start_date = dt.datetime(2020,10,10)
end_date = dt.datetime(2024,1,8)

def get_tickers(tickers,start,end):
    
    
    return yf.download(tickers,start=start_date,end=end_date)['Close']




stock_tickers = ['AAPL', 'TGT', 'MCD', 'IBM', 'TSLA']
ETF_tickers = ['BND', 'HYG', 'TIP', 'IEF', 'LQD']
FX_tickers = ['USDJPY=X', 'USDGBP=X', 'USDEUR=X', 'USDAUD=X', 'USDRUB=X']
CRYPTO_tickers = ['BTC-USD', 'ETH-USD', 'SOL-USD', 'ADA-USD', 'XRP-USD']

stocks_df = get_tickers(stock_tickers, start=start_date, end=end_date)
FX_df = get_tickers(FX_tickers, start=start_date, end=end_date)
ETF_df = get_tickers(ETF_tickers, start=start_date, end=end_date)
CRYPTO_df = get_tickers(CRYPTO_tickers, start=start_date, end=end_date)

risk_free_rate = 0.05

assets = (stocks_df,ETF_df,FX_df,CRYPTO_df)


stocks_df = stocks_df.dropna()
FX_df = FX_df.dropna()
ETF_df = ETF_df.dropna()
CRYPTO_df = CRYPTO_df.dropna()







def get_returns(assets):
    returns = {}
    for model_name, model in zip(["stocks","ETF's","FX","Crypto"],assets):
        model_returns = model.pct_change().dropna()
        returns[model_name] = model_returns
        print(f'Returns for {model_name}:')
        print(model_returns.head())
    return returns


get_returns(assets)
# Out:
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# Returns for stocks:
# Ticker          AAPL       IBM       MCD       TGT      TSLA
# Date
# 2020-10-13 -0.026527 -0.016587  0.005484  0.006502  0.009835
# 2020-10-14  0.000743  0.006715  0.001188 -0.010082  0.032800
# 2020-10-15 -0.003961 -0.008337  0.008874  0.009087 -0.026924
# 2020-10-16 -0.014000  0.008327 -0.001176 -0.003264 -0.020518
# 2020-10-19 -0.025542 -0.003256 -0.014692 -0.005275 -0.020106
# Returns for ETF's:
# Ticker           BND       HYG       IEF       LQD       TIP
# Date
# 2020-10-13  0.000795 -0.004451  0.002229 -0.000958  0.000000
# 2020-10-14  0.000567 -0.002471  0.000329  0.000959  0.000000
# 2020-10-15 -0.000567 -0.000708 -0.001070 -0.001032 -0.000317
# 2020-10-16 -0.000794 -0.001180 -0.000577 -0.001697  0.000396
# 2020-10-19 -0.000909 -0.003545 -0.001649 -0.001921 -0.002374
# Returns for FX:
# Ticker      USDAUD=X  USDEUR=X  USDGBP=X  USDJPY=X  USDRUB=X
# Date
# 2020-10-13  0.001763  0.000059 -0.002606 -0.002774  0.002104
# 2020-10-14  0.006628  0.006298  0.010087  0.001244  0.000334
# 2020-10-15  0.003210 -0.000153 -0.005924 -0.003138  0.008952
# 2020-10-16  0.007489  0.003147  0.008549  0.002102  0.002642
# 2020-10-19 -0.001071 -0.000714 -0.001987  0.000636 -0.005181
# Returns for Crypto:
# Ticker       ADA-USD   BTC-USD   ETH-USD   SOL-USD   XRP-USD
# Date
# 2020-10-11  0.014406  0.007774  0.011253  0.008515  0.005620
# 2020-10-12  0.032815  0.015037  0.033558  0.066140  0.002843
# 2020-10-13 -0.010742 -0.011204 -0.016869 -0.070412 -0.000480
# 2020-10-14 -0.014285  0.000316 -0.004477 -0.037538 -0.026822
# 2020-10-15 -0.006170  0.005761 -0.005382 -0.020824 -0.014063
# {'stocks': Ticker          AAPL       IBM       MCD       TGT      TSLA
#  Date
#  2020-10-13 -0.026527 -0.016587  0.005484  0.006502  0.009835
#  2020-10-14  0.000743  0.006715  0.001188 -0.010082  0.032800
#  2020-10-15 -0.003961 -0.008337  0.008874  0.009087 -0.026924
#  2020-10-16 -0.014000  0.008327 -0.001176 -0.003264 -0.020518
#  2020-10-19 -0.025542 -0.003256 -0.014692 -0.005275 -0.020106
#  ...              ...       ...       ...       ...       ...
#  2023-12-29 -0.005424 -0.001221  0.002265 -0.000842 -0.018564
#  2024-01-02 -0.035787 -0.012534  0.001787  0.004775 -0.000241
#  2024-01-03 -0.007488 -0.008669 -0.008921 -0.030957 -0.040134
#  2024-01-04 -0.012700  0.004747 -0.009002  0.011394 -0.002181
#  2024-01-05 -0.004013 -0.010568 -0.009426  0.003565 -0.001849
#
#  [813 rows x 5 columns],
#  "ETF's": Ticker           BND       HYG       IEF       LQD       TIP
#  Date
#  2020-10-13  0.000795 -0.004451  0.002229 -0.000958  0.000000
#  2020-10-14  0.000567 -0.002471  0.000329  0.000959  0.000000
#  2020-10-15 -0.000567 -0.000708 -0.001070 -0.001032 -0.000317
#  2020-10-16 -0.000794 -0.001180 -0.000577 -0.001697  0.000396
#  2020-10-19 -0.000909 -0.003545 -0.001649 -0.001921 -0.002374
#  ...              ...       ...       ...       ...       ...
#  2023-12-29 -0.002306 -0.003862 -0.002484 -0.003691 -0.001208
#  2024-01-02 -0.004215 -0.003359 -0.003735 -0.006778 -0.001396
#  2024-01-03  0.000819 -0.002723  0.002395 -0.002274  0.001584
#  2024-01-04 -0.004502 -0.003900 -0.006025 -0.005563 -0.004651
#  2024-01-05 -0.003015  0.000783 -0.003658 -0.003576 -0.002243
#
#  [813 rows x 5 columns],
#  'FX': Ticker      USDAUD=X  USDEUR=X  USDGBP=X  USDJPY=X  USDRUB=X
#  Date
#  2020-10-13  0.001763  0.000059 -0.002606 -0.002774  0.002104
#  2020-10-14  0.006628  0.006298  0.010087  0.001244  0.000334
#  2020-10-15  0.003210 -0.000153 -0.005924 -0.003138  0.008952
#  2020-10-16  0.007489  0.003147  0.008549  0.002102  0.002642
#  2020-10-19 -0.001071 -0.000714 -0.001987  0.000636 -0.005181
#  ...              ...       ...       ...       ...       ...
#  2024-01-01  0.000852  0.001118  0.000313 -0.003380  0.008763
#  2024-01-02  0.001466  0.001548  0.000094  0.001235  0.000000
#  2024-01-03  0.006623  0.008864  0.008376  0.007291  0.013226
#  2024-01-04  0.004409  0.001280 -0.004039  0.005937  0.017368
#  2024-01-05  0.004385 -0.001792 -0.000773  0.012350 -0.007068
#
#  [844 rows x 5 columns],
#  'Crypto': Ticker       ADA-USD   BTC-USD   ETH-USD   SOL-USD   XRP-USD
#  Date
#  2020-10-11  0.014406  0.007774  0.011253  0.008515  0.005620
#  2020-10-12  0.032815  0.015037  0.033558  0.066140  0.002843
#  2020-10-13 -0.010742 -0.011204 -0.016869 -0.070412 -0.000480
#  2020-10-14 -0.014285  0.000316 -0.004477 -0.037538 -0.026822
#  2020-10-15 -0.006170  0.005761 -0.005382 -0.020824 -0.014063
#  ...              ...       ...       ...       ...       ...
#  2024-01-03 -0.079880 -0.046928 -0.061581 -0.075196 -0.068413
#  2024-01-04  0.023832  0.031081  0.026360  0.065755  0.009691
#  2024-01-05 -0.051396 -0.000390 -0.000172 -0.048524 -0.019958
#  2024-01-06 -0.033514 -0.003929 -0.011911 -0.061224 -0.013832
#  2024-01-07 -0.055303 -0.001048 -0.008368 -0.048812 -0.029500
#
#  [1184 rows x 5 columns]}

# %%
def correlation_heatmap(assets):
    for model_name, model in zip(["stocks","ETF's","FX","Crypto"],assets):
        plt.figure(figsize=(10,6))
        sns.heatmap(model.corr(), fmt="f", annot=True, cmap="coolwarm")
        plt.title(f'Correlation Heatmap for {model_name}')
        plt.show()
        

correlation_heatmap(assets)

# %%
def plot_assets(assets):
    for model_name, model in zip(["stocks","ETF's","FX","Crypto"], assets):
        plt.figure(figsize=(10,6))
        plt.plot(model)
        plt.title(f'{model_name} Prices')
        plt.xlabel('Date')
        plt.ylabel('Price')
        plt.legend(model.columns)
        plt.show()


plot_assets(assets)

# %%
def portfolio_optimization(assets):
    for model_name, model in zip(["stocks","ETF's","FX","Crypto"], assets):
        mu = expected_returns.mean_historical_return(model)
        risk = risk_models.sample_cov(model)
        ef = EfficientFrontier(mu, risk)
        weights = ef.max_sharpe()
        sharpe_ratio = ef.portfolio_performance()[2]
        ### optimal portfolio performance
        
        optimal_expected_returns = ef.portfolio_performance()[0]
        optimal_portfolio_risk = ef.portfolio_performance()[1]
        optimal_sharpe_ratio = (optimal_expected_returns - risk_free_rate) / optimal_portfolio_risk
        print(f'Expected returns of {model_name}: {mu}')
        print(f'Risk (Covariance Matrix) of {model_name}: {risk}')
        print(f'Optimized weights for {model_name}: {weights}')
        print(f'{model_name}; --Sharpe Ratio-- {sharpe_ratio}')
        print(f'Optimal Expected Returns on {model_name}: {optimal_expected_returns}')
        print(f'Risk of Optimal Portfolio {model_name}: {optimal_portfolio_risk}')
        print(f'Sharpe Ratio of optimal Portfolio {model_name}: {optimal_sharpe_ratio}')

        
    return model

portfolio_optimization(assets)
# Out:
# Expected returns of stocks: Ticker
# AAPL    0.130323
# IBM     0.142364
# MCD     0.103751
# TGT    -0.026247
# TSLA    0.159252
# dtype: float64
# Risk (Covariance Matrix) of stocks: Ticker      AAPL       IBM       MCD       TGT      TSLA
# Ticker
# AAPL    0.079114  0.015844  0.019041  0.032962  0.084533
# IBM     0.015844  0.046903  0.012046  0.019776  0.012333
# MCD     0.019041  0.012046  0.027502  0.015987  0.017875
# TGT     0.032962  0.019776  0.015987  0.115830  0.056130
# TSLA    0.084533  0.012333  0.017875  0.056130  0.345598
# Optimized weights for stocks: OrderedDict([('AAPL', 0.0917453400310647), ('IBM', 0.4265055647241404), ('MCD', 0.4546619432719549), ('TGT', 0.0), ('TSLA', 0.0270871519728399)])
# stocks; --Sharpe Ratio-- 0.8051127115347748
# Optimal Expected Returns on stocks: 0.12416064588099476
# Risk of Optimal Portfolio stocks: 0.15421523483874588
# Sharpe Ratio of optimal Portfolio stocks: 0.4808905291266478
# Expected returns of ETF's: Ticker
# BND   -0.032701
# HYG    0.017248
# IEF   -0.054681
# LQD   -0.036695
# TIP   -0.009505
# dtype: float64
# Risk (Covariance Matrix) of ETF's: Ticker       BND       HYG       IEF       LQD       TIP
# Ticker
# BND     0.004116  0.003106  0.005201  0.005759  0.003595
# HYG     0.003106  0.007428  0.003207  0.005555  0.002795
# IEF     0.005201  0.003207  0.006946  0.006983  0.004657
# LQD     0.005759  0.005555  0.006983  0.009080  0.004990
# TIP     0.003595  0.002795  0.004657  0.004990  0.004956
# Optimized weights for ETF's: OrderedDict([('BND', 7.3745564e-08), ('HYG', 0.9999995702411077), ('IEF', 3.592916645e-07), ('LQD', 2.294895811e-07), ('TIP', -2.322687737e-07)])
# ETF's; --Sharpe Ratio-- 0.20012448509494685
# Optimal Expected Returns on ETF's: 0.01724795067258639
# Risk of Optimal Portfolio ETF's: 0.08618610893316374
# Sharpe Ratio of optimal Portfolio ETF's: -0.3800154077359778
# Expected returns of FX: Ticker
# USDAUD=X    0.022463
# USDEUR=X    0.023081
# USDGBP=X    0.008105
# USDJPY=X    0.098666
# USDRUB=X    0.052889
# dtype: float64
# Risk (Covariance Matrix) of FX: Ticker    USDAUD=X  USDEUR=X  USDGBP=X  USDJPY=X   USDRUB=X
# Ticker
# USDAUD=X  0.011569  0.005454  0.007070  0.004181  -0.033026
# USDEUR=X  0.005454  0.005928  0.005324  0.003024  -0.013567
# USDGBP=X  0.007070  0.005324  0.008618  0.003652  -0.012226
# USDJPY=X  0.004181  0.003024  0.003652  0.008303   0.015729
# USDRUB=X -0.033026 -0.013567 -0.012226  0.015729  62.045657
# Optimized weights for FX: OrderedDict([('USDAUD=X', -1.95203848e-08), ('USDEUR=X', -9.1798689e-09), ('USDGBP=X', -8.74628843e-08), ('USDJPY=X', 1.0000001166842443), ('USDRUB=X', -4.20246e-10)])
# FX; --Sharpe Ratio-- 1.0828257394576886
# Optimal Expected Returns on FX: 0.09866634528665373
# Risk of Optimal Portfolio FX: 0.09111932021127313
# Sharpe Ratio of optimal Portfolio FX: 0.5340946922542209
# Expected returns of Crypto: Ticker
# ADA-USD    0.390439
# BTC-USD    0.335255
# ETH-USD    0.463854
# SOL-USD    1.157908
# XRP-USD    0.179234
# dtype: float64
# Risk (Covariance Matrix) of Crypto: Ticker    ADA-USD   BTC-USD   ETH-USD   SOL-USD   XRP-USD
# Ticker
# ADA-USD  0.703728  0.285897  0.397273  0.492565  0.469491
# BTC-USD  0.285897  0.285665  0.297631  0.306232  0.281292
# ETH-USD  0.397273  0.297631  0.480118  0.461663  0.389140
# SOL-USD  0.492565  0.306232  0.461663  1.199341  0.492423
# XRP-USD  0.469491  0.281292  0.389140  0.492423  1.021158
# Optimized weights for Crypto: OrderedDict([('ADA-USD', 0.0), ('BTC-USD', 0.1723337293681074), ('ETH-USD', 0.0), ('SOL-USD', 0.8276662706318929), ('XRP-USD', 0.0)])
# Crypto; --Sharpe Ratio-- 1.0608796650382182
# Optimal Expected Returns on Crypto: 1.0161370863418797
# Risk of Optimal Portfolio Crypto: 0.9578250199614047
# Sharpe Ratio of optimal Portfolio Crypto: 1.0086780635369181
# Ticker       ADA-USD       BTC-USD      ETH-USD     SOL-USD   XRP-USD
# Date
# 2020-10-10  0.105025  11296.361328   370.967590    2.406090  0.254290
# 2020-10-11  0.106538  11384.181641   375.142059    2.426578  0.255719
# 2020-10-12  0.110034  11555.363281   387.731262    2.587072  0.256446
# 2020-10-13  0.108852  11425.899414   381.190765    2.404910  0.256323
# 2020-10-14  0.107297  11429.506836   379.484039    2.314635  0.249448
# ...              ...           ...          ...         ...       ...
# 2024-01-03  0.557286  42848.175781  2210.761963   98.594437  0.582580
# 2024-01-04  0.570567  44179.921875  2269.038086  105.077538  0.588226
# 2024-01-05  0.541242  44162.691406  2268.647217   99.978790  0.576486
# 2024-01-06  0.523103  43989.195312  2241.624756   93.857719  0.568512
# 2024-01-07  0.494174  43943.097656  2222.865967   89.276344  0.551741
#
# [1185 rows x 5 columns]

# %%
df = pd.concat(assets,axis=1,keys=["stocks","ETFs","FX","Crypto"])

df = df.dropna()


def full_portfolio_heatmap(df):
    plt.figure(figsize=(15,6))
    sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap="coolwarm")
    plt.title('Correlation Matrix for Full Portfolio')
    plt.show()
    

full_portfolio_heatmap(df)

# %%
stock_ticker = ['AAPL','IBM','^GSPC','TSLA','DIS','MCD','GOOGL']


df = yf.download(tickers=stock_ticker,start=start_date,end=end_date)['Close']
df.head(10)

print(df.pct_change().dropna())



def single_index_model(stock_ticker, sp500, risk_free_rate):
    stock_data = df[stock_ticker].to_frame()
    sp500_data = df[sp500].to_frame()
    stock_data['Excess_Return'] = stock_data[stock_ticker] - risk_free_rate
    sp500_data['Excess_Return'] = sp500_data['^GSPC'] - risk_free_rate
    model = sm.OLS(endog=stock_data['Excess_Return'], exog=sm.add_constant(sp500_data['Excess_Return'])).fit()
    print(f'single index for each stock ticker{stock_data}')
    print(model.summary())
    plt.figure(figsize=(8,6))
    sns.scatterplot(x=sp500_data['Excess_Return'], y=stock_data['Excess_Return'], label=stock_ticker)
    sns.lineplot(x=sp500_data['Excess_Return'], y=model.fittedvalues, color='red', label='Security Market Line')
    plt.title(f'Single Index Model for {stock_ticker}')
    plt.xlabel('Market Excess Return')
    plt.ylabel(f'{stock_ticker} Excess Return')
    plt.legend()
    plt.show()



single_index_model("AAPL","^GSPC",risk_free_rate)
single_index_model("IBM","^GSPC",risk_free_rate)
single_index_model("MCD","^GSPC",risk_free_rate)
single_index_model("TSLA",'^GSPC',risk_free_rate)
single_index_model("DIS","^GSPC",risk_free_rate)
single_index_model("AAPL","^GSPC", risk_free_rate)
# Out:
# [*********************100%***********************]  7 of 7 completed
# Ticker          AAPL       DIS     GOOGL       IBM       MCD      TSLA  \
# Date
# 2020-10-13 -0.026527  0.031928  0.001585 -0.016587  0.005484  0.009835
# 2020-10-14  0.000743 -0.018378 -0.002316  0.006715  0.001188  0.032800
# 2020-10-15 -0.003961  0.006083 -0.005098 -0.008337  0.008874 -0.026924
# 2020-10-16 -0.014000 -0.004318  0.007863  0.008327 -0.001176 -0.020518
# 2020-10-19 -0.025542 -0.020345 -0.024080 -0.003256 -0.014692 -0.020106
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-29 -0.005424 -0.001217 -0.003851 -0.001221  0.002265 -0.018564
# 2024-01-02 -0.035787  0.004652 -0.010881 -0.012534  0.001787 -0.000241
# 2024-01-03 -0.007488  0.010363  0.005428 -0.008669 -0.008921 -0.040134
# 2024-01-04 -0.012700 -0.011893 -0.018212  0.004747 -0.009002 -0.002181
# 2024-01-05 -0.004013  0.003754 -0.004839 -0.010568 -0.009426 -0.001849
#
# Ticker         ^GSPC
# Date
# 2020-10-13 -0.006307
# 2020-10-14 -0.006623
# 2020-10-15 -0.001528
# 2020-10-16  0.000135
# 2020-10-19 -0.016330
# ...              ...
# 2023-12-29 -0.002826
# 2024-01-02 -0.005661
# 2024-01-03 -0.008016
# 2024-01-04 -0.003428
# 2024-01-05  0.001826
#
# [813 rows x 7 columns]
# single index for each stock ticker                  AAPL  Excess_Return
# Date
# 2020-10-12  121.435638     121.385638
# 2020-10-13  118.214287     118.164287
# 2020-10-14  118.302155     118.252155
# 2020-10-15  117.833580     117.783580
# 2020-10-16  116.183853     116.133853
# ...                ...            ...
# 2023-12-29  191.591385     191.541385
# 2024-01-02  184.734985     184.684985
# 2024-01-03  183.351776     183.301776
# 2024-01-04  181.023163     180.973163
# 2024-01-05  180.296707     180.246707
#
# [814 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Excess_Return   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.502
# Method:                 Least Squares   F-statistic:                     820.8
# Date:                Wed, 08 Jan 2025   Prob (F-statistic):          2.64e-125
# Time:                        22:11:33   Log-Likelihood:                -3372.9
# No. Observations:                 814   AIC:                             6750.
# Df Residuals:                     812   BIC:                             6759.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           -46.6676      6.943     -6.721      0.000     -60.296     -33.039
# Excess_Return     0.0475      0.002     28.650      0.000       0.044       0.051
# ==============================================================================
# Omnibus:                      204.990   Durbin-Watson:                   0.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.438
# Skew:                          -0.237   Prob(JB):                     3.69e-10
# Kurtosis:                       1.972   Cond. No.                     5.43e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# single index for each stock ticker                   IBM  Excess_Return
# Date
# 2020-10-12   99.982353      99.932353
# 2020-10-13   98.323982      98.273982
# 2020-10-14   98.984184      98.934184
# 2020-10-15   98.158936      98.108936
# 2020-10-16   98.976334      98.926334
# ...                ...            ...
# 2023-12-29  157.843948     157.793948
# 2024-01-02  155.865463     155.815463
# 2024-01-03  154.514343     154.464343
# 2024-01-04  155.247803     155.197803
# 2024-01-05  153.607117     153.557117
#
# [814 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Excess_Return   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     205.0
# Date:                Wed, 08 Jan 2025   Prob (F-statistic):           1.25e-41
# Time:                        22:11:33   Log-Likelihood:                -3203.4
# No. Observations:                 814   AIC:                             6411.
# Df Residuals:                     812   BIC:                             6420.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            38.4836      5.638      6.826      0.000      27.417      49.551
# Excess_Return     0.0193      0.001     14.318      0.000       0.017       0.022
# ==============================================================================
# Omnibus:                       29.367   Durbin-Watson:                   0.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.061
# Skew:                           0.244   Prob(JB):                     7.26e-05
# Kurtosis:                       2.430   Cond. No.                     5.43e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# single index for each stock ticker                   MCD  Excess_Return
# Date
# 2020-10-12  205.198257     205.148257
# 2020-10-13  206.323608     206.273608
# 2020-10-14  206.568634     206.518634
# 2020-10-15  208.401794     208.351794
# 2020-10-16  208.156754     208.106754
# ...                ...            ...
# 2023-12-29  289.494537     289.444537
# 2024-01-02  290.011993     289.961993
# 2024-01-03  287.424683     287.374683
# 2024-01-04  284.837372     284.787372
# 2024-01-05  282.152405     282.102405
#
# [814 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Excess_Return   R-squared:                       0.197
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     199.3
# Date:                Wed, 08 Jan 2025   Prob (F-statistic):           1.24e-40
# Time:                        22:11:34   Log-Likelihood:                -3753.6
# No. Observations:                 814   AIC:                             7511.
# Df Residuals:                     812   BIC:                             7521.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            82.7029     11.083      7.462      0.000      60.948     104.458
# Excess_Return     0.0374      0.003     14.118      0.000       0.032       0.043
# ==============================================================================
# Omnibus:                    28516.739   Durbin-Watson:                   0.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.298
# Skew:                           0.187   Prob(JB):                     8.96e-16
# Kurtosis:                       1.620   Cond. No.                     5.43e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# single index for each stock ticker                  TSLA  Excess_Return
# Date
# 2020-10-12  147.433334     147.383334
# 2020-10-13  148.883331     148.833331
# 2020-10-14  153.766663     153.716663
# 2020-10-15  149.626663     149.576663
# 2020-10-16  146.556671     146.506671
# ...                ...            ...
# 2023-12-29  248.479996     248.429996
# 2024-01-02  248.419998     248.369998
# 2024-01-03  238.449997     238.399997
# 2024-01-04  237.929993     237.879993
# 2024-01-05  237.490005     237.440005
#
# [814 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Excess_Return   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     465.8
# Date:                Wed, 08 Jan 2025   Prob (F-statistic):           5.20e-82
# Time:                        22:11:34   Log-Likelihood:                -4265.7
# No. Observations:                 814   AIC:                             8535.
# Df Residuals:                     812   BIC:                             8545.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -205.6796     20.792     -9.892      0.000    -246.491    -164.868
# Excess_Return     0.1071      0.005     21.583      0.000       0.097       0.117
# ==============================================================================
# Omnibus:                       57.674   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.985
# Skew:                           0.267   Prob(JB):                     8.38e-07
# Kurtosis:                       2.265   Cond. No.                     5.43e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# single index for each stock ticker                   DIS  Excess_Return
# Date
# 2020-10-12  123.445007     123.395007
# 2020-10-13  127.386330     127.336330
# 2020-10-14  125.045235     124.995235
# 2020-10-15  125.805840     125.755840
# 2020-10-16  125.262550     125.212550
# ...                ...            ...
# 2023-12-29   89.478874      89.428874
# 2024-01-02   89.895103      89.845103
# 2024-01-03   90.826660      90.776660
# 2024-01-04   89.746445      89.696445
# 2024-01-05   90.083397      90.033397
#
# [814 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Excess_Return   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.093
# Date:                Wed, 08 Jan 2025   Prob (F-statistic):              0.148
# Time:                        22:11:34   Log-Likelihood:                -4093.4
# No. Observations:                 814   AIC:                             8191.
# Df Residuals:                     812   BIC:                             8200.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           102.8515     16.825      6.113      0.000      69.825     135.877
# Excess_Return     0.0058      0.004      1.447      0.148      -0.002       0.014
# ==============================================================================
# Omnibus:                     9295.039   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.743
# Skew:                           0.341   Prob(JB):                     3.97e-19
# Kurtosis:                       1.574   Cond. No.                     5.43e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# single index for each stock ticker                  AAPL  Excess_Return
# Date
# 2020-10-12  121.435638     121.385638
# 2020-10-13  118.214287     118.164287
# 2020-10-14  118.302155     118.252155
# 2020-10-15  117.833580     117.783580
# 2020-10-16  116.183853     116.133853
# ...                ...            ...
# 2023-12-29  191.591385     191.541385
# 2024-01-02  184.734985     184.684985
# 2024-01-03  183.351776     183.301776
# 2024-01-04  181.023163     180.973163
# 2024-01-05  180.296707     180.246707
#
# [814 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Excess_Return   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.502
# Method:                 Least Squares   F-statistic:                     820.8
# Date:                Wed, 08 Jan 2025   Prob (F-statistic):          2.64e-125
# Time:                        22:11:34   Log-Likelihood:                -3372.9
# No. Observations:                 814   AIC:                             6750.
# Df Residuals:                     812   BIC:                             6759.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           -46.6676      6.943     -6.721      0.000     -60.296     -33.039
# Excess_Return     0.0475      0.002     28.650      0.000       0.044       0.051
# ==============================================================================
# Omnibus:                      204.990   Durbin-Watson:                   0.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.438
# Skew:                          -0.237   Prob(JB):                     3.69e-10
# Kurtosis:                       1.972   Cond. No.                     5.43e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df = yf.download(stock_tickers,start=start_date,end=end_date)
df.head(10)



from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

X = df[['Open','Close','High','Volume']]
X_scaled = MinMaxScaler().fit_transform(X)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

cc = []
for i in range(1,2):
    kmeans = KMeans(n_clusters=i,init='k-means++',n_init=20,random_state=42).fit(X_pca)
    cc.append(kmeans.inertia_)



### The Elbow Method
plt.plot(range(1,21),cc,marker='*')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.title('The Elbow Method')
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed
#   File "C:\Users\katsa\miniconda3\envs\cuda\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\katsa\miniconda3\envs\cuda\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\katsa\miniconda3\envs\cuda\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\katsa\miniconda3\envs\cuda\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
kmeans = KMeans(n_clusters=16,init='k-means++',n_init=20,random_state=42).fit(X_pca)
labels = kmeans.fit_predict(X_pca)
X['Cluster 1'] = labels
X['Cluster 2'] = labels


plt.scatter(X_pca[:,0],X_pca[:,1],c=X['Cluster 1'],s=300,marker='*',edgecolors='r')
plt.scatter(X_pca[:,0],X_pca[:,1],c=X['Cluster 2'],s=300,marker='X',edgecolors='m')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],marker='o',color='m')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('K-Means Clustering')
plt.show()

# %%
from sklearn.metrics import silhouette_score
lables = kmeans.fit_predict(X_pca)
X['Cluster'] = labels
sh = silhouette_score(X_pca, labels)
print(f'The silhoutte score is {sh*100:.2f}%')
print(kmeans.inertia_)
# Out:
# The silhoutte score is 47.56%
# 14.71667535958533
